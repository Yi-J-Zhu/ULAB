# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.loadtxt("041119/aba1_1.txt",unpack = True)
print(x)
# Out:
# [[482.357 482.49  482.624 ... 615.864 615.992 616.12 ]
#  [  1.      1.      1.    ...   1.      1.      1.   ]
#  [525.    517.    536.    ... 262.    230.    218.   ]]

# %%
plt.plot(x[0], x[2])

fig = plt.gcf()
fig.set_size_inches(9, 6)
plt.savefig("si vs raman.png", dpi=300)
