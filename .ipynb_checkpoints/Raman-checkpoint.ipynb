# %%
## Delta^2 DRV
# %pwd
import numpy as np
import matplotlib.pyplot as plt
#in_file = open("041119/aba1_1.txt")
#print(in_file.read())
open("1.txt","r")
x1 = np.loadtxt("041119/aba1_1.txt")
x2 = np.loadtxt("041119/silicon_1.txt")
x5 = np.loadtxt("041119/FINAL_aba_1.txt")
x7 = np.loadtxt("041119/abc_maybe_1_1.txt")

print(len(x1))
x3,x4,x6,x8 = [],[],[],[]
for i in range(740,761):
    x3.append((x1[i][2]-x2[i][2])**2)
    x4.append(x1[i][0])
    x6.append((x1[i][2]-x5[i][2])**2)
    x8.append((x1[i][2]-x7[i][2])**2)
plt.figure()
plt.plot(x4,x3,"r--")
plt.figure()
plt.plot(x4,x6,"r--")
plt.figure()
plt.plot(x4,x8,"r--")
plt.show()
print(x8)
# Out:
# 1024
# [33489.0, 59536.0, 51984.0, 37636.0, 5476.0, 144.0, 7569.0, 2401.0, 63001.0, 46656.0, 85849.0, 17956.0, 400.0, 38809.0, 8464.0, 5041.0, 17424.0, 22201.0, 38809.0, 29584.0, 46656.0]
